# %% [markdown]
# # Titanic Disaster
#
# Bu tekrar bölümünde, farklı özelliklere sahip tüm yolcuları listeleyen ünlü  [Titanic](https://drive.google.com/file/d/1td-RTqXsV0Cc3z6Ad3Vk-15bH42L40aY/view) veri setini inceleyeceğiz.

# %% [markdown]
# ❓`matplotlib`, `numpy` ve `pandas` kütüphanelerini her zamanki şekilde yükleyerek başla.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ❓CSV verisini yükleyip `titanic_df` adlı bir değişkene ata.
#
# CSV dosyasına şu URL’den ulaşılabilir: https://drive.google.com/file/d/1td-RTqXsV0Cc3z6Ad3Vk-15bH42L40aY/view
#
# <details>
#     <summary>💡 <strong>Hint</strong> - Click to reveal</summary>
#     Try using <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html"><code>pandas.DataFrame.read_csv</code></a>
# </details>

# %%
titanic_df = pd.read_csv("titanic_dataset.csv")

# %% [markdown]
# ❓ Veri setini her zamanki yöntemlerle incele (`shape`, `dtypes`, `describe()`, `info()`, `isnull().sum()`).
#
#  `B` tuşuna basarak yeni hücreler eklemekten çekinme.

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 687 satırda  `Cabin` 687 satırda  bilgisinin eksik olduğu (NaN olduğu) görülüyor.
#
# ❓`titanic_df` içerisindeki  `Cabin` sütunundan kurtulmak için [`pandas.DataFrame.drop`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) fonksiyonunu kullan.

# %%
titanic_df.drop(columns=["Cabin"])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# ## Classes Analysis
#
# Bilet dağılımına bir göz atalım.
#
# ❓ Bir `groupby()`,kullanarak, her sınıf (1, 2 veya 3) için satılan bilet sayısını hesaplayan bir`pclass_df` dataframe oluştur.

# %%
pclass_df = titanic_df.groupby("Pclass").size().reset_index(name="TicketCount")
pclass_df.head()
# Out:
#    Pclass  TicketCount
# 0       1          216
# 1       2          184
# 2       3          491

# %% [markdown]
# Sayıya bakmak çok görsel değil, veriyi bir grafikle anlamlandırmayı deneyelim.
#
# ❓ Bir önceki soruda oluşturduğun `pclass_df` dataframe’ini bir bar chart olarak plot et.

# %%
pclass_df.plot(x="Pclass", y="TicketCount",kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# Şimdi hayatta kalanlara **survivors** bakalım.
#
# ❓ Her yolcu sınıfının hayatta kalma oranını  *survival rate* gösteren bir bar chart plot et.
# `0` ,  o sınıfta kimsenin hayatta kalmadığı, `1` ise herkesin hayatta kaldığı anlamına gelir.

# %%
survivors = titanic_df.groupby("Pclass")["Survived"].mean()
survivors_df = survivors.reset_index()
survivors_df.head()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
survivors_df.plot(x = "Pclass", y="Survived" , kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ### Gender Analysis
#
# `Sex`  sütununa bir göz atalım.
#
# ❓ Bu sütunda kullanılan farklı değerleri kontrol etmek için [`pandas.Series.unique`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html) fonksiyonunu kullan.

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ❓ Her cinsiyetin hayatta kalma oranını *survival rate*  gösteren bir bar chart plot et.
# Verilere göre, hangi cinsiyetin hayatta kalma ihtimali daha yüksekti?

# %%
sex_df = titanic_df.groupby("Sex")["Survived"].mean().reset_index()

# %%
sex_df.plot(x="Sex", y="Survived", kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# Her cinsiyet için toplam yolcu sayısını ve toplam hayatta kalan sayısını birlikte gösterdiğimiz daha şık bir histogram oluşturalım.
#
# ❓`Total` ve `Survived`  olmak üzere iki sütunlu, `male` and `female` şeklinde iki satırlı bir `survivors_df` DataFrame oluştur ve plot et.

# %%
total = titanic_df.groupby("Sex")["Survived"].count()
survived = titanic_df.groupby("Sex")["Survived"].sum()
survivors_df = pd.DataFrame({
    "Total": total,
    "Survived" : survived
})
survivors_df.plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# ## Children
#
# Önceki analiz yaşları dikkate almıyordu. Bir çocuğu bir yetişkinden ayırmak ve bunun hayatta kalma oranlarını *survival rates* nasıl etkilediğini görmek istiyoruz.
#
# ❓ Boolean indexing kullanarak yalnızca çocuk yolcuların satırlarını içeren bir `children_df` oluştur.

# %%
titanic_df["ischild"] = np.where(titanic_df["Age"] < 18,1,0)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  ischild
# 0      0         A/5 21171   7.2500   NaN        S        0
# 1      0          PC 17599  71.2833   C85        C        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0
# 3      0            113803  53.1000  C123        S        0
# 4      0            373450   8.0500   NaN        S        0

# %% [markdown]
# ❓ Titanic’te kaç çocuk vardı?

# %%
titanic_df["ischild"].sum()
# Out:
# 113

# %% [markdown]
# ❓Kaç çocuk hayatta kaldı?

# %%
num_survived_child = titanic_df[(titanic_df["ischild"] == 1) & (titanic_df["Survived"] == 1)]
print(num_survived_child)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
#         Sex    Age  SibSp  Parch         Ticket     Fare Cabin Embarked  \
# 9    female  14.00      1      0         237736  30.0708   NaN        C
# 10   female   4.00      1      1        PP 9549  16.7000    G6        S
# 22   female  15.00      0      0         330923   8.0292   NaN        Q
# 39   female  14.00      1      0           2651  11.2417   NaN        C
# 43   female   3.00      1      2  SC/Paris 2123  41.5792   NaN        C
# ..      ...    ...    ...    ...            ...      ...   ...      ...
# 830  female  15.00      1      0           2659  14.4542   NaN        C
# 831    male   0.83      1      1          29106  18.7500   NaN        S
# 853  female  16.00      0      1       PC 17592  39.4000   D28        S
# 869    male   4.00      1      1         347742  11.1333   NaN        S
# 875  female  15.00      0      0           2667   7.2250   NaN        C
#
#      ischild
# 9          1
# 10         1
# 22         1
# 39         1
# 43         1
# ..       ...
# 830        1
# 831        1
# 853        1
# 869        1
# 875        1
#
# [61 rows x 13 columns]

# %% [markdown]
# ❓ Her kategori için( `male`, `female`, `children`).hayatta kalanlar / toplam oranını gösteren bir bar chart plot et. Unutma: `male` istatistiklerinden erkek çocukları, `female` istatistiklerinden ise kız çocukları çıkarman **substract** gerekiyor.

# %%
children_rate = titanic_df[titanic_df["ischild"] == 1]["Survived"].mean()
female_rate = titanic_df[(titanic_df["Sex"] == "female") & (titanic_df["ischild"] == 0)]["Survived"].mean()
male_rate = titanic_df[(titanic_df["Sex"] == "male") & (titanic_df["ischild"] == 0)]["Survived"].mean()
survival_rates = pd.DataFrame({
    "Group" : ["Children","Female","Male"],
    "SurvivalRate" : [ children_rate, female_rate, male_rate]
    })

survival_rates.plot(x="Group", y="SurvivalRate", kind="bar", legend=False)
# Out:
# <Axes: xlabel='Group'>

# %% [markdown]
# ## [Opsiyonal] Big families

# %% [markdown]
# ❓ Daha büyük ailelerin hayatta kalması daha mı zordu?
#
# Burada, yolcunun aile büyüklüğünü gösteren yeni bir sütunu `DataFrame` ine ekleyeceksin.

# %%
titanic_df["familysize"] = titanic_df["SibSp"] + titanic_df["Parch"] + 1

titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  ischild  familysize
# 0      0         A/5 21171   7.2500   NaN        S        0           2
# 1      0          PC 17599  71.2833   C85        C        0           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0           1
# 3      0            113803  53.1000  C123        S        0           2
# 4      0            373450   8.0500   NaN        S        0           1

# %%
family_survival = titanic_df.groupby("familysize")["Survived"].mean()
family_survival.plot(kind="bar", figsize=(10,5), title="Survival Rate by Family Size")
# Out:
# <Axes: title={'center': 'Survival Rate by Family Size'}, xlabel='familysize'>

# %% [markdown]
# ## [Opsiyonal] Distinguished titles

# %% [markdown]
# ❓ Tahliye sırasında ünvanı (Mr, Mrs, Dr vb.) olan yolculara daha fazla öncelik verildi mi?
#
# Bunu incelemek için, bazı string manipülasyonları yaparak her yolcu için ünvanını içeren yeni bir sütun oluştur.

# %%
titanic_df["Title"] = titanic_df["Name"].str.extract(r',\s*([^\.]+)\.')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  ischild  familysize Title
# 0      0         A/5 21171   7.2500   NaN        S        0           2    Mr
# 1      0          PC 17599  71.2833   C85        C        0           2   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0           1  Miss
# 3      0            113803  53.1000  C123        S        0           2   Mrs
# 4      0            373450   8.0500   NaN        S        0           1    Mr

# %%
title_survival = titanic_df.groupby("Title")["Survived"].mean()

# %%
title_survival.plot(kind="bar")
# Out:
# <Axes: xlabel='Title'>
